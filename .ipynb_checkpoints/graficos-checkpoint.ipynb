# %%
import matplotlib.pyplot as plt

def graficar(eixo_X, eixo_Y,title):        
    plt.plot(eixo_X, eixo_Y)
    plt.ylabel(title)
    #análise exploratória visual
    plt.grid(True)
    plt.legend(loc = ('best'))
    plt.show()
